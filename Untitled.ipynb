# %% [markdown]
# # STEAM GAMES ANALYSIS

# %% [markdown]
# ## Introduction

# %% [markdown]
# Steam is a video game digital distribution service by Valve. It was launched as a standalone software client in September 2003 as a way for Valve to provide automatic updates for their games, and expanded to include games from third-party publishers. Steam has also expanded into an online web-based and mobile digital storefront. Steam offers digital rights management (DRM), server hosting, video streaming, and social networking services. It also provides the user with installation and automatic updating of games, and community features such as friends lists and groups, cloud storage, and in-game voice and chat functionality.
#
# The software provides a freely available application programming interface (API) called Steamworks, which developers can use to integrate many of Steam's functions into their products, including in-game achievements, microtransactions, and support for user-created content through Steam Workshop. Though initially developed for use on Microsoft Windows operating systems, versions for macOS and Linux were later released. Mobile apps were also released for iOS, Android, and Windows Phone in the 2010s. The platform also offers a small selection of other content, including design software, hardware, game soundtracks, anime, and films.
#
# The Steam platform is the largest digital distribution platform for PC gaming, holding around 75% of the market space in 2013. By 2017, users purchasing games through Steam totaled roughly US$4.3 billion, representing at least 18% of global PC game sales. By 2019, the service had over 34,000 games with over 95 million monthly active users. The success of Steam has led to the development of a line of Steam Machine microconsoles, which include the SteamOS operating system and Steam Controllers.

# %% [markdown]
# Source: https://en.wikipedia.org/wiki/Steam_(service)

# %% [markdown]
# ## Data description and objectives

# %% [markdown]
# There are a lot of games in Steam platform, because of it there a lot of information about it.
#
# Data:
# + Names of games
# + Release dates of games
# + The language of games (is game supprts English language)
# + Developers of games
# + Platforms of games
# + Required ages of games
# + Categories of games
# + Genres of games
# + Tags of games
# + Count of achievments of games
# + Ratings of games
# + Playtimes of games
# + Count of owners of games
# + Prices of games
#
#
# Plan:
# + Clear dataset
# + Get data from official website (https://store.steampowered.com/)
# + Data visualization (Charts, Graphs, Tables)
# + Analyze results
# + Conclusion

# %% [markdown]
# ## Used libraries

# %%
import time                            #To set timeouts for search
import pandas as pd                    #To work with datasets
import requests                        #To scrap data
from selenium import webdriver         #To work with web-site while scrapping
from bs4 import BeautifulSoup          #To orginize data after scrap

# %% [markdown]
# ## Working with dataset

# %% [markdown]
# The usen dataset was downloaded from kaggle.com.
#
# Url: https://www.kaggle.com/nikdavis/steam-store-games
#
# This dataset is open sorced and any user can user data from it

# %%
data = pd.read_csv('archive/steam.csv', index_col=0)    #To read csv file with dataset
data                                                    #To show table
# Out:
#                                name release_date  english           developer  \
# appid
# 10                   Counter-Strike   2000-11-01        1               Valve
# 20            Team Fortress Classic   1999-04-01        1               Valve
# 30                    Day of Defeat   2003-05-01        1               Valve
# 40               Deathmatch Classic   2001-06-01        1               Valve
# 50        Half-Life: Opposing Force   1999-11-01        1    Gearbox Software
# ...                             ...          ...      ...                 ...
# 1065230             Room of Pandora   2019-04-24        1         SHEN JIAWEI
# 1065570                   Cyber Gun   2019-04-23        1      Semyon Maximov
# 1065650            Super Star Blast   2019-04-24        1         EntwicklerX
# 1066700  New Yankee 7: Deer Hunters   2019-04-17        1  Yustas Game Studio
# 1069460                   Rune Lord   2019-04-24        1    Adept Studios GD
#
#                     publisher          platforms  required_age  \
# appid
# 10                      Valve  windows;mac;linux             0
# 20                      Valve  windows;mac;linux             0
# 30                      Valve  windows;mac;linux             0
# 40                      Valve  windows;mac;linux             0
# 50                      Valve  windows;mac;linux             0
# ...                       ...                ...           ...
# 1065230           SHEN JIAWEI            windows             0
# 1065570      BekkerDev Studio            windows             0
# 1065650           EntwicklerX            windows             0
# 1066700  Alawar Entertainment        windows;mac             0
# 1069460  Alawar Entertainment        windows;mac             0
#
#                                                 categories  \
# appid
# 10       Multi-player;Online Multi-Player;Local Multi-P...
# 20       Multi-player;Online Multi-Player;Local Multi-P...
# 30                   Multi-player;Valve Anti-Cheat enabled
# 40       Multi-player;Online Multi-Player;Local Multi-P...
# 50       Single-player;Multi-player;Valve Anti-Cheat en...
# ...                                                    ...
# 1065230                   Single-player;Steam Achievements
# 1065570                                      Single-player
# 1065650  Single-player;Multi-player;Co-op;Shared/Split ...
# 1066700                          Single-player;Steam Cloud
# 1069460                          Single-player;Steam Cloud
#
#                          genres                 steamspy_tags  achievements  \
# appid
# 10                       Action        Action;FPS;Multiplayer             0
# 20                       Action        Action;FPS;Multiplayer             0
# 30                       Action  FPS;World War II;Multiplayer             0
# 40                       Action        Action;FPS;Multiplayer             0
# 50                       Action             FPS;Action;Sci-fi             0
# ...                         ...                           ...           ...
# 1065230  Adventure;Casual;Indie        Adventure;Indie;Casual             7
# 1065570  Action;Adventure;Indie        Action;Indie;Adventure             0
# 1065650     Action;Casual;Indie           Action;Indie;Casual            24
# 1066700  Adventure;Casual;Indie        Indie;Casual;Adventure             0
# 1069460  Adventure;Casual;Indie        Indie;Casual;Adventure             0
#
#          positive_ratings  negative_ratings  average_playtime  \
# appid
# 10                 124534              3339             17612
# 20                   3318               633               277
# 30                   3416               398               187
# 40                   1273               267               258
# 50                   5250               288               624
# ...                   ...               ...               ...
# 1065230                 3                 0                 0
# 1065570                 8                 1                 0
# 1065650                 0                 1                 0
# 1066700                 2                 0                 0
# 1069460                 4                 0                 0
#
#          median_playtime             owners  price
# appid
# 10                   317  10000000-20000000   7.19
# 20                    62   5000000-10000000   3.99
# 30                    34   5000000-10000000   3.99
# 40                   184   5000000-10000000   3.99
# 50                   415   5000000-10000000   3.99
# ...                  ...                ...    ...
# 1065230                0            0-20000   2.09
# 1065570                0            0-20000   1.69
# 1065650                0            0-20000   3.99
# 1066700                0            0-20000   5.19
# 1069460                0            0-20000   5.19
#
# [27075 rows x 17 columns]

# %%
data[data['platforms'].str.contains('mac')]   #To show all games that for mac (Example)
# Out:
#                                      name release_date  english  \
# appid
# 10                         Counter-Strike   2000-11-01        1
# 20                  Team Fortress Classic   1999-04-01        1
# 30                          Day of Defeat   2003-05-01        1
# 40                     Deathmatch Classic   2001-06-01        1
# 50              Half-Life: Opposing Force   1999-11-01        1
# ...                                   ...          ...      ...
# 1055970   Argonauts Agency: Pandora's Box   2019-04-17        1
# 1057710           Funny Bunny: Adventures   2019-04-24        1
# 1059710  New Yankee 6: In Pharaoh's Court   2019-04-03        1
# 1066700        New Yankee 7: Deer Hunters   2019-04-17        1
# 1069460                         Rune Lord   2019-04-24        1
#
#                    developer             publisher          platforms  \
# appid
# 10                     Valve                 Valve  windows;mac;linux
# 20                     Valve                 Valve  windows;mac;linux
# 30                     Valve                 Valve  windows;mac;linux
# 40                     Valve                 Valve  windows;mac;linux
# 50          Gearbox Software                 Valve  windows;mac;linux
# ...                      ...                   ...                ...
# 1055970            Workroom7             Workroom7        windows;mac
# 1057710  mPower Games Studio   mPower Games Studio  windows;mac;linux
# 1059710   Yustas Game Studio  Alawar Entertainment        windows;mac
# 1066700   Yustas Game Studio  Alawar Entertainment        windows;mac
# 1069460     Adept Studios GD  Alawar Entertainment        windows;mac
#
#          required_age                                         categories  \
# appid
# 10                  0  Multi-player;Online Multi-Player;Local Multi-P...
# 20                  0  Multi-player;Online Multi-Player;Local Multi-P...
# 30                  0              Multi-player;Valve Anti-Cheat enabled
# 40                  0  Multi-player;Online Multi-Player;Local Multi-P...
# 50                  0  Single-player;Multi-player;Valve Anti-Cheat en...
# ...               ...                                                ...
# 1055970             0       Single-player;Steam Achievements;Steam Cloud
# 1057710             0                   Single-player;Steam Achievements
# 1059710             0                          Single-player;Steam Cloud
# 1066700             0                          Single-player;Steam Cloud
# 1069460             0                          Single-player;Steam Cloud
#
#                                 genres                 steamspy_tags  \
# appid
# 10                              Action        Action;FPS;Multiplayer
# 20                              Action        Action;FPS;Multiplayer
# 30                              Action  FPS;World War II;Multiplayer
# 40                              Action        Action;FPS;Multiplayer
# 50                              Action             FPS;Action;Sci-fi
# ...                                ...                           ...
# 1055970     Casual;Simulation;Strategy    Strategy;Casual;Simulation
# 1057710  Action;Adventure;Casual;Indie       Casual;Adventure;Arcade
# 1059710         Adventure;Casual;Indie        Indie;Casual;Adventure
# 1066700         Adventure;Casual;Indie        Indie;Casual;Adventure
# 1069460         Adventure;Casual;Indie        Indie;Casual;Adventure
#
#          achievements  positive_ratings  negative_ratings  average_playtime  \
# appid
# 10                  0            124534              3339             17612
# 20                  0              3318               633               277
# 30                  0              3416               398               187
# 40                  0              1273               267               258
# 50                  0              5250               288               624
# ...               ...               ...               ...               ...
# 1055970            29                 1                 0                 0
# 1057710            22                 3                 0                 0
# 1059710             0                 2                 0                 0
# 1066700             0                 2                 0                 0
# 1069460             0                 4                 0                 0
#
#          median_playtime             owners  price
# appid
# 10                   317  10000000-20000000   7.19
# 20                    62   5000000-10000000   3.99
# 30                    34   5000000-10000000   3.99
# 40                   184   5000000-10000000   3.99
# 50                   415   5000000-10000000   3.99
# ...                  ...                ...    ...
# 1055970                0            0-20000   4.79
# 1057710                0            0-20000   7.19
# 1059710                0            0-20000   5.19
# 1066700                0            0-20000   5.19
# 1069460                0            0-20000   5.19
#
# [8066 rows x 17 columns]

# %%
data[['price']].plot(color='lightgreen')     #Visualize data as graph (Example) (Price per appid)

# %%
data.groupby(["developer"]).first()      #Getting first games of each developer
# Out:
#                                                            name release_date  \
# developer
# #workshop                                             Tiny Snow   2019-02-27
# 'What Day is it?' Games                     Brazilian Adventure   2018-03-19
# (STCG) Smoker The Car Game                  Smoker The Car Game   2018-09-14
# +7 Software                                          Final Days   2018-09-18
# +Mpact Games, LLC.                        Hanako: Honor & Blade   2017-10-08
# ...                                                         ...          ...
# 魂动天下                                        The mysterious ship   2018-05-25
# 魔力乐章                                                贤者挽歌之马略卡协奏曲   2018-06-04
# 魔术工坊                                      Successor of the Moon   2019-03-14
# 黄昏フロンティア                    東方憑依華　～ Antinomy of Common Flowers.   2018-01-05
# 수프림                                                  Dream rose   2019-02-27
#
#                             english                   publisher    platforms  \
# developer
# #workshop                         0                    NVLMaker      windows
# 'What Day is it?' Games           1      What Day is it?' Games  windows;mac
# (STCG) Smoker The Car Game        1  (STCG) Smoker The Car Game      windows
# +7 Software                       1                 +7 Software      windows
# +Mpact Games, LLC.                1          +Mpact Games, LLC.      windows
# ...                             ...                         ...          ...
# 魂动天下                              1                        魂动天下      windows
# 魔力乐章                              0                        魔力乐章      windows
# 魔术工坊                              1                  SakuraGame      windows
# 黄昏フロンティア                          0           SUNFISH Co., Ltd.      windows
# 수프림                               0                         수프림      windows
#
#                             required_age  \
# developer
# #workshop                              0
# 'What Day is it?' Games                0
# (STCG) Smoker The Car Game             0
# +7 Software                            0
# +Mpact Games, LLC.                     0
# ...                                  ...
# 魂动天下                                   0
# 魔力乐章                                   0
# 魔术工坊                                   0
# 黄昏フロンティア                               0
# 수프림                                    0
#
#                                                                    categories  \
# developer
# #workshop                        Single-player;Steam Achievements;Steam Cloud
# 'What Day is it?' Games                             Single-player;Steam Cloud
# (STCG) Smoker The Car Game     Single-player;Partial Controller Support;Stats
# +7 Software                 Single-player;Multi-player;Co-op;Online Co-op;...
# +Mpact Games, LLC.          Multi-player;Online Multi-Player;Steam Achieve...
# ...                                                                       ...
# 魂动天下                                                            Single-player
# 魔力乐章                                                            Single-player
# 魔术工坊                        Single-player;Steam Achievements;Partial Contr...
# 黄昏フロンティア                    Single-player;Multi-player;Online Multi-Player...
# 수프림                                                             Single-player
#
#                                                                        genres  \
# developer
# #workshop                                              Adventure;Casual;Indie
# 'What Day is it?' Games                                Adventure;Casual;Indie
# (STCG) Smoker The Car Game  Casual;Indie;Racing;Simulation;Sports;Early Ac...
# +7 Software                                               Action;Casual;Indie
# +Mpact Games, LLC.                                  Action;Indie;Early Access
# ...                                                                       ...
# 魂动天下                                   Gore;Adventure;Casual;Indie;Simulation
# 魔力乐章                                                                      RPG
# 魔术工坊                                                   Action;Adventure;Indie
# 黄昏フロンティア                                                         Action;Indie
# 수프림                                                           Adventure;Indie
#
#                                                    steamspy_tags  \
# developer
# #workshop                                 Adventure;Indie;Casual
# 'What Day is it?' Games                   Adventure;Indie;Casual
# (STCG) Smoker The Car Game             Early Access;Indie;Casual
# +7 Software                                  Action;Indie;Casual
# +Mpact Games, LLC.            Early Access;Multiplayer;Swordplay
# ...                                                          ...
# 魂动天下                                      Adventure;Indie;Casual
# 魔力乐章                                                   RPG;Anime
# 魔术工坊                                      Action;Indie;Adventure
# 黄昏フロンティア                    Great Soundtrack;Fighting;2D Fighter
# 수프림                                              Adventure;Indie
#
#                             achievements  positive_ratings  negative_ratings  \
# developer
# #workshop                              9               653                29
# 'What Day is it?' Games                0                 2                 0
# (STCG) Smoker The Car Game             0                 2                 2
# +7 Software                           90                41                 5
# +Mpact Games, LLC.                    18                74                16
# ...                                  ...               ...               ...
# 魂动天下                                   0                 3                 0
# 魔力乐章                                   0                 6                 1
# 魔术工坊                                   7                44                10
# 黄昏フロンティア                               0              1286               135
# 수프림                                    0                 5                 0
#
#                             average_playtime  median_playtime       owners  \
# developer
# #workshop                                  0                0      0-20000
# 'What Day is it?' Games                    0                0      0-20000
# (STCG) Smoker The Car Game                 0                0      0-20000
# +7 Software                                0                0      0-20000
# +Mpact Games, LLC.                         0                0      0-20000
# ...                                      ...              ...          ...
# 魂动天下                                       0                0      0-20000
# 魔力乐章                                       0                0      0-20000
# 魔术工坊                                       0                0      0-20000
# 黄昏フロンティア                                 264              264  20000-50000
# 수프림                                        0                0      0-20000
#
#                             price
# developer
# #workshop                    2.89
# 'What Day is it?' Games      5.19
# (STCG) Smoker The Car Game   0.79
# +7 Software                  5.49
# +Mpact Games, LLC.           5.19
# ...                           ...
# 魂动天下                         1.69
# 魔力乐章                         2.09
# 魔术工坊                         1.69
# 黄昏フロンティア                    19.49
# 수프림                          3.99
#
# [17113 rows x 16 columns]

# %% [markdown]
# ## Checking all columns for null values

# %%
check = data.notnull()   #Finding null values
check
# Out:
#          name  release_date  english  developer  publisher  platforms  \
# appid
# 10       True          True     True       True       True       True
# 20       True          True     True       True       True       True
# 30       True          True     True       True       True       True
# 40       True          True     True       True       True       True
# 50       True          True     True       True       True       True
# ...       ...           ...      ...        ...        ...        ...
# 1065230  True          True     True       True       True       True
# 1065570  True          True     True       True       True       True
# 1065650  True          True     True       True       True       True
# 1066700  True          True     True       True       True       True
# 1069460  True          True     True       True       True       True
#
#          required_age  categories  genres  steamspy_tags  achievements  \
# appid
# 10               True        True    True           True          True
# 20               True        True    True           True          True
# 30               True        True    True           True          True
# 40               True        True    True           True          True
# 50               True        True    True           True          True
# ...               ...         ...     ...            ...           ...
# 1065230          True        True    True           True          True
# 1065570          True        True    True           True          True
# 1065650          True        True    True           True          True
# 1066700          True        True    True           True          True
# 1069460          True        True    True           True          True
#
#          positive_ratings  negative_ratings  average_playtime  \
# appid
# 10                   True              True              True
# 20                   True              True              True
# 30                   True              True              True
# 40                   True              True              True
# 50                   True              True              True
# ...                   ...               ...               ...
# 1065230              True              True              True
# 1065570              True              True              True
# 1065650              True              True              True
# 1066700              True              True              True
# 1069460              True              True              True
#
#          median_playtime  owners  price
# appid
# 10                  True    True   True
# 20                  True    True   True
# 30                  True    True   True
# 40                  True    True   True
# 50                  True    True   True
# ...                  ...     ...    ...
# 1065230             True    True   True
# 1065570             True    True   True
# 1065650             True    True   True
# 1066700             True    True   True
# 1069460             True    True   True
#
# [27075 rows x 17 columns]

# %%
check[~check['name']]    #Searching null values from dataframe
# Out:
# Empty DataFrame
# Columns: [name, release_date, english, developer, publisher, platforms, required_age, categories, genres, steamspy_tags, achievements, positive_ratings, negative_ratings, average_playtime, median_playtime, owners, price]
# Index: []

# %%
check.all()              #Checking all columns for null
# Out:
# name                True
# release_date        True
# english             True
# developer           True
# publisher           True
# platforms           True
# required_age        True
# categories          True
# genres              True
# steamspy_tags       True
# achievements        True
# positive_ratings    True
# negative_ratings    True
# average_playtime    True
# median_playtime     True
# owners              True
# price               True
# dtype: bool

# %%
data.dropna()    #Remove all rows with null value in any column
# Out:
#                                name release_date  english           developer  \
# appid
# 10                   Counter-Strike   2000-11-01        1               Valve
# 20            Team Fortress Classic   1999-04-01        1               Valve
# 30                    Day of Defeat   2003-05-01        1               Valve
# 40               Deathmatch Classic   2001-06-01        1               Valve
# 50        Half-Life: Opposing Force   1999-11-01        1    Gearbox Software
# ...                             ...          ...      ...                 ...
# 1065230             Room of Pandora   2019-04-24        1         SHEN JIAWEI
# 1065570                   Cyber Gun   2019-04-23        1      Semyon Maximov
# 1065650            Super Star Blast   2019-04-24        1         EntwicklerX
# 1066700  New Yankee 7: Deer Hunters   2019-04-17        1  Yustas Game Studio
# 1069460                   Rune Lord   2019-04-24        1    Adept Studios GD
#
#                     publisher          platforms  required_age  \
# appid
# 10                      Valve  windows;mac;linux             0
# 20                      Valve  windows;mac;linux             0
# 30                      Valve  windows;mac;linux             0
# 40                      Valve  windows;mac;linux             0
# 50                      Valve  windows;mac;linux             0
# ...                       ...                ...           ...
# 1065230           SHEN JIAWEI            windows             0
# 1065570      BekkerDev Studio            windows             0
# 1065650           EntwicklerX            windows             0
# 1066700  Alawar Entertainment        windows;mac             0
# 1069460  Alawar Entertainment        windows;mac             0
#
#                                                 categories  \
# appid
# 10       Multi-player;Online Multi-Player;Local Multi-P...
# 20       Multi-player;Online Multi-Player;Local Multi-P...
# 30                   Multi-player;Valve Anti-Cheat enabled
# 40       Multi-player;Online Multi-Player;Local Multi-P...
# 50       Single-player;Multi-player;Valve Anti-Cheat en...
# ...                                                    ...
# 1065230                   Single-player;Steam Achievements
# 1065570                                      Single-player
# 1065650  Single-player;Multi-player;Co-op;Shared/Split ...
# 1066700                          Single-player;Steam Cloud
# 1069460                          Single-player;Steam Cloud
#
#                          genres                 steamspy_tags  achievements  \
# appid
# 10                       Action        Action;FPS;Multiplayer             0
# 20                       Action        Action;FPS;Multiplayer             0
# 30                       Action  FPS;World War II;Multiplayer             0
# 40                       Action        Action;FPS;Multiplayer             0
# 50                       Action             FPS;Action;Sci-fi             0
# ...                         ...                           ...           ...
# 1065230  Adventure;Casual;Indie        Adventure;Indie;Casual             7
# 1065570  Action;Adventure;Indie        Action;Indie;Adventure             0
# 1065650     Action;Casual;Indie           Action;Indie;Casual            24
# 1066700  Adventure;Casual;Indie        Indie;Casual;Adventure             0
# 1069460  Adventure;Casual;Indie        Indie;Casual;Adventure             0
#
#          positive_ratings  negative_ratings  average_playtime  \
# appid
# 10                 124534              3339             17612
# 20                   3318               633               277
# 30                   3416               398               187
# 40                   1273               267               258
# 50                   5250               288               624
# ...                   ...               ...               ...
# 1065230                 3                 0                 0
# 1065570                 8                 1                 0
# 1065650                 0                 1                 0
# 1066700                 2                 0                 0
# 1069460                 4                 0                 0
#
#          median_playtime             owners  price
# appid
# 10                   317  10000000-20000000   7.19
# 20                    62   5000000-10000000   3.99
# 30                    34   5000000-10000000   3.99
# 40                   184   5000000-10000000   3.99
# 50                   415   5000000-10000000   3.99
# ...                  ...                ...    ...
# 1065230                0            0-20000   2.09
# 1065570                0            0-20000   1.69
# 1065650                0            0-20000   3.99
# 1066700                0            0-20000   5.19
# 1069460                0            0-20000   5.19
#
# [27075 rows x 17 columns]

# %% [markdown]
# There no null values in dataset

# %% [markdown]
# ## Checking for duplicated data

# %%
duplicate = data.duplicated()
duplicate
# Out:
# appid
# 10         False
# 20         False
# 30         False
# 40         False
# 50         False
#            ...
# 1065230    False
# 1065570    False
# 1065650    False
# 1066700    False
# 1069460    False
# Length: 27075, dtype: bool

# %%
duplicate[duplicate].index.values
# Out:
# array([], dtype=int64)

# %% [markdown]
# There no duplicating data in dataset

# %% [markdown]
# ## Scrapping data from official Website (https://store.steampowered.com/)

# %%
temp = []                                                               #Creating necessary lists where we store data
names = []
p1 = []
p2 = []
p3 = []
p4 = []
for x in range(10, 10000, 10):                                          #The url of pages are incrementing by 10
    req = requests.get("https://store.steampowered.com/app/"+str(x))    #Requesting data from site
    soup = BeautifulSoup(req.content,'lxml')                            #Do data more readible
    name = soup.find_all("div", class_="apphub_AppName")                #Finding all "div" with name "apphub_AppName"
    t1 = soup.find_all("span", class_="responsive_hidden")              #Finding all "span" with name "responsive_hidden"
    t2 = soup.find_all("span", class_="game_review_summary")            #Finding all "span" with name "game_review_summary"
    if x % 1000 == 0:                                                   #Creating checkpoints to prevent data lost
        dic = {'name': names, 'Recent Reviews': p1, 'Recent Reviews Number': p2, 'Overall Reviews': p3, 'Overall Reviews Names': p4}    
        df = pd.DataFrame(dic)
        df.to_csv('checkpoint'+str(x)+'.csv') 
    if len(t2) == 0:                                                    #There some pages where no information
        continue                                                        #Because of it we just skip it
    if len(t1) == 0:
        continue
    if len(name) == 0:
        continue
    names.append(name[0].text)                                          #Adding necessary data to our lists
    p1.append(t2[0].text)
    p2.append(t1[0].text.replace('\r', '').replace('\t','').replace('\n','').replace('(','').replace(')',''))
    p3.append(t2[0].text)
    p4.append(t1[0].text.replace('\r', '').replace('\t','').replace('\n','').replace('(','').replace(')',''))
    req.close()                                                         #Close our requests
    print(name[0].text + " DONE; " + str(x))                            #To visualize checked pages

dic = {'name': names, 'Recent Reviews': p1, 'Recent Reviews Number': p2, 'Overall Reviews': p3, 'Overall Reviews Names': p4}    
df = pd.DataFrame(dic)
df.to_csv('GFG.csv')                                                    #Save all data to "GFG.csv"
# Out:
# Counter-Strike DONE; 10
# Team Fortress Classic DONE; 20
# Day of Defeat DONE; 30
# Deathmatch Classic DONE; 40
# Half-Life: Opposing Force DONE; 50
# Ricochet DONE; 60
# Half-Life DONE; 70
# Counter-Strike: Condition Zero DONE; 80
# Counter-Strike: Condition Zero DONE; 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-34f601a46d34> in <module>
#       7 p4 = []
#       8 for x in range(10, 10000, 10):
# ----> 9     req = requests.get("https://store.steampowered.com/app/"+str(x))
#      10     soup = BeautifulSoup(req.content,'lxml')
#      11     i = 0
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
scrdata = pd.read_csv('GFG.csv', index_col=0)       #To read csv file with scrapped data 
scrdata                                             #To show all data
# Out:
#                           name           Recent Reviews Recent Reviews Number  \
# 0               Counter-Strike  Overwhelmingly Positive                 1,190
# 1        Team Fortress Classic            Very Positive                    69
# 2                Day of Defeat            Very Positive                    23
# 3           Deathmatch Classic            Very Positive                    11
# 4    Half-Life: Opposing Force            Very Positive                   188
# ..                         ...                      ...                   ...
# 357               Blade Kitten            Very Positive                   806
# 358               Blade Kitten            Very Positive                   806
# 359             Haunted House™                    Mixed                    20
# 360               Star Raiders          Mostly Negative                    24
# 361            The UnderGarden                    Mixed                    51
#
#              Overall Reviews Overall Reviews Names
# 0    Overwhelmingly Positive                 1,190
# 1              Very Positive                    69
# 2              Very Positive                    23
# 3              Very Positive                    11
# 4              Very Positive                   188
# ..                       ...                   ...
# 357            Very Positive                   806
# 358            Very Positive                   806
# 359                    Mixed                    20
# 360          Mostly Negative                    24
# 361                    Mixed                    51
#
# [362 rows x 5 columns]

# %%
scrduplicate = scrdata.duplicated()           #Get duplicaded rows from dataframe
scrduplicate
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 357    False
# 358     True
# 359    False
# 360    False
# 361    False
# Length: 362, dtype: bool

# %%
scrduplicate[scrduplicate].index.values       #Get rows of duplicated data
# Out:
# array([  8,  19,  28,  38,  46,  51,  52,  71,  74,  85, 102, 106, 145,
#        155, 158, 160, 170, 176, 177, 186, 187, 205, 209, 211, 215, 218,
#        222, 235, 236, 237, 242, 243, 248, 250, 262, 269, 272, 277, 279,
#        281, 297, 304, 308, 309, 312, 317, 318, 330, 331, 332, 333, 337,
#        339, 340, 345, 349, 358], dtype=int64)

# %%
scrdata.drop(scrduplicate[scrduplicate].index.values)  #Remove duplicated values
# Out:
#                           name           Recent Reviews Recent Reviews Number  \
# 0               Counter-Strike  Overwhelmingly Positive                 1,190
# 1        Team Fortress Classic            Very Positive                    69
# 2                Day of Defeat            Very Positive                    23
# 3           Deathmatch Classic            Very Positive                    11
# 4    Half-Life: Opposing Force            Very Positive                   188
# ..                         ...                      ...                   ...
# 356           Star Trek Online          Mostly Positive                   159
# 357               Blade Kitten            Very Positive                   806
# 359             Haunted House™                    Mixed                    20
# 360               Star Raiders          Mostly Negative                    24
# 361            The UnderGarden                    Mixed                    51
#
#              Overall Reviews Overall Reviews Names
# 0    Overwhelmingly Positive                 1,190
# 1              Very Positive                    69
# 2              Very Positive                    23
# 3              Very Positive                    11
# 4              Very Positive                   188
# ..                       ...                   ...
# 356          Mostly Positive                   159
# 357            Very Positive                   806
# 359                    Mixed                    20
# 360          Mostly Negative                    24
# 361                    Mixed                    51
#
# [305 rows x 5 columns]

# %%
scrcheck = scrdata.notnull()   #Finding null values
scrcheck
# Out:
#      name  Recent Reviews  Recent Reviews Number  Overall Reviews  \
# 0    True            True                   True             True
# 1    True            True                   True             True
# 2    True            True                   True             True
# 3    True            True                   True             True
# 4    True            True                   True             True
# ..    ...             ...                    ...              ...
# 357  True            True                   True             True
# 358  True            True                   True             True
# 359  True            True                   True             True
# 360  True            True                   True             True
# 361  True            True                   True             True
#
#      Overall Reviews Names
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ..                     ...
# 357                   True
# 358                   True
# 359                   True
# 360                   True
# 361                   True
#
# [362 rows x 5 columns]

# %%
scrcheck.all() #Getting columns with null values
# Out:
# name                     True
# Recent Reviews           True
# Recent Reviews Number    True
# Overall Reviews          True
# Overall Reviews Names    True
# dtype: bool

# %%
pd.merge(data,scrdata,on='name')   #Joining scrapped dataframe with dataset from Kaggle
# Out:
#                           name release_date  english               developer  \
# 0               Counter-Strike   2000-11-01        1                   Valve
# 1        Team Fortress Classic   1999-04-01        1                   Valve
# 2                Day of Defeat   2003-05-01        1                   Valve
# 3           Deathmatch Classic   2001-06-01        1                   Valve
# 4    Half-Life: Opposing Force   1999-11-01        1        Gearbox Software
# ..                         ...          ...      ...                     ...
# 304                   eversion   2010-06-07        1  Zaratustra Productions
# 305                    ArcaniA   2010-10-11        1      Spellbound Studios
# 306        Supreme Commander 2   2010-03-01        1       Gas Powered Games
# 307   Call of Duty®: Black Ops   2010-11-08        1                Treyarch
# 308   Numen: Contest of Heroes   2010-06-03        1         CINEMAX, s.r.o.
#
#                   publisher          platforms  required_age  \
# 0                     Valve  windows;mac;linux             0
# 1                     Valve  windows;mac;linux             0
# 2                     Valve  windows;mac;linux             0
# 3                     Valve  windows;mac;linux             0
# 4                     Valve  windows;mac;linux             0
# ..                      ...                ...           ...
# 304  Zaratustra Productions  windows;mac;linux             0
# 305              THQ Nordic            windows             0
# 306             Square Enix            windows             0
# 307              Activision            windows            18
# 308         CINEMAX, s.r.o.            windows             0
#
#                                             categories    genres  \
# 0    Multi-player;Online Multi-Player;Local Multi-P...    Action
# 1    Multi-player;Online Multi-Player;Local Multi-P...    Action
# 2                Multi-player;Valve Anti-Cheat enabled    Action
# 3    Multi-player;Online Multi-Player;Local Multi-P...    Action
# 4    Single-player;Multi-player;Valve Anti-Cheat en...    Action
# ..                                                 ...       ...
# 304  Single-player;Steam Achievements;Steam Trading...     Indie
# 305                                      Single-player       RPG
# 306  Single-player;Multi-player;Steam Achievements;...  Strategy
# 307  Single-player;Multi-player;Co-op;Steam Achieve...    Action
# 308                                      Single-player       RPG
#
#                     steamspy_tags  ...  positive_ratings  negative_ratings  \
# 0          Action;FPS;Multiplayer  ...            124534              3339
# 1          Action;FPS;Multiplayer  ...              3318               633
# 2    FPS;World War II;Multiplayer  ...              3416               398
# 3          Action;FPS;Multiplayer  ...              1273               267
# 4               FPS;Action;Sci-fi  ...              5250               288
# ..                            ...  ...               ...               ...
# 304       Platformer;Indie;Horror  ...               955                92
# 305   RPG;Open World;Singleplayer  ...               735               763
# 306           Strategy;RTS;Sci-fi  ...              5336               903
# 307            Action;FPS;Zombies  ...             14201              1839
# 308      RPG;Action RPG;Mythology  ...                66                69
#
#      average_playtime  median_playtime             owners  price  \
# 0               17612              317  10000000-20000000   7.19
# 1                 277               62   5000000-10000000   3.99
# 2                 187               34   5000000-10000000   3.99
# 3                 258              184   5000000-10000000   3.99
# 4                 624              415   5000000-10000000   3.99
# ..                ...              ...                ...    ...
# 304               466              466       50000-100000   3.99
# 305               398              571      200000-500000  17.99
# 306              1834             2894    1000000-2000000   8.99
# 307              2672              517    2000000-5000000  29.99
# 308                 0                0       50000-100000   4.99
#
#               Recent Reviews Recent Reviews Number          Overall Reviews  \
# 0    Overwhelmingly Positive                 1,190  Overwhelmingly Positive
# 1              Very Positive                    69            Very Positive
# 2              Very Positive                    23            Very Positive
# 3              Very Positive                    11            Very Positive
# 4              Very Positive                   188            Very Positive
# ..                       ...                   ...                      ...
# 304            Very Positive                   914            Very Positive
# 305                    Mixed                    24                    Mixed
# 306            Very Positive                    69            Very Positive
# 307  Overwhelmingly Positive                   226  Overwhelmingly Positive
# 308                    Mixed                   110                    Mixed
#
#     Overall Reviews Names
# 0                   1,190
# 1                      69
# 2                      23
# 3                      11
# 4                     188
# ..                    ...
# 304                   914
# 305                    24
# 306                    69
# 307                   226
# 308                   110
#
# [309 rows x 21 columns]
